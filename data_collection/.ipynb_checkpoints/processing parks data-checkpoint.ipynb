# %%
__author__ = "me"
__date__ = "2015_10_13"

# %pylab inline
import pandas as pd
import numpy as np
import geopandas as gp

import pylab as plt
import os

import requests
s = requests.get("https://raw.githubusercontent.com/Casyfill/CUSP_templates/master/Py/fbMatplotlibrc.json").json()
plt.rcParams.update(s)

import topojson
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/casy/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:855: UserWarning: svg.embed_char_paths is deprecated and replaced with svg.fonttype; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
PARQA = os.getenv('PARQA')

# %%
parks = gp.read_file(PARQA + '/data/parks_computed.geojson' ).to_crs(epsg=2236)

# %%
parks.area.describe()
# Out:
# count    2.001000e+03
# mean     6.250142e+05
# std      3.966844e+06
# min      2.623140e+01
# 25%      6.619141e+03
# 50%      3.267254e+04
# 75%      9.209570e+04
# max      1.177342e+08
# dtype: float64

# %%
6.250142e+05
# Out:
# 625014.2

# %%
parks.area[parks.area>200000].hist(bins=20)

# %%
print len(parks)
print len(parks[parks.area>300000])
# Out:
# 2001
# 252

# %%
parks[parks.area>300000].plot(figsize=(18,18))

# %%
x = parks[parks.area>300000]

# %%
path = PARQA + '/Parqa_tool/data/parqs.json'

with open(path,'w') as f:
    f.write(x.to_json())

# %%
from topojson import topojson

#give it a path in and out
topojson(path,path.replace('.json','_t.json'), quantization=1e6, simplify=0.0001)
